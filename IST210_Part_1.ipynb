# %% [markdown]
# # Group Assignment 1
#
#
# ### Group Members:
# #### Alison Chow
# #### Colby Collins
# #### Nicholas Lacey
# #### George Massie
# ---
# ## PART 1
# ### Idea 1
#
# a. i. The idea is a repository for vehicles, associated gas efficiency, and to see if there are relationships between those two factors and the amount of miles driven on average.
# ---
# a. ii. This idea has more than likely been done before but we believe it will be a good learning experience from a database/SQL type approach.
# ---
# a. iii. This could be loosely based on already existing products like GasBuddy but it is a new idea to our group.
# ---
# a. iv. A typical interaction would be using this data with local government/other interested parties to see how gas prices affect total distance traveled in vehicles with that data being able to be analyzed, applied, and projected to yearly gas price trends.
# ---
#    1. Gas prices at various local gas stations.
#    2. Which gas stations were used to refill which vehicle.
#    3. Vehicle and general gas efficiency of the vehicle.
#    4. Vehicle and vehicle owner.
#    5. Vehicle and amount of distance traveled per week.
# ---
# b. i. The "end-user" data for this idea is idea 5.
# ---
# b. ii. Attributes would include owner names, vehicle make/model, type of gas used to refill vehicles at gas stations, distanced traveled in highway/urbran settings, and an attribute that designates if a car is eco-friendly or not.
# ---
# c. We do not have any relevent images to add for this idea.
# ---
# d. The goal of this idea is to see if there is a relationship or an influence between the price of gas and the amount of distance driven. This would be useful data not only for the sake of having data but also to see if the implementation of "eco-friendly" cars could influence behaviors.
# ---
#
# ***

# %% [markdown]
# ### Idea 2
#
# a. i. The main idea in this instance is to create a collection of data that can be used to track meat prices, consumption of meat, and where certain types are sold more than others.
# ---
# a. ii. From what I know, this collection of data does not exist and could be beneficial to grocers, butchers, and markets nationally.
# ---
# a. iii.  I imagine some companies already have explored this idea before, but i would consider this an original idea.
# ---
# a. iv. A typical day in this business would include communicating with multiple meat vendors, helping them find the best prices for meat products.
# ---
#    1. Type of meat, location, price.
#    2. Shipping cost to location.
#    3. Location of suppliers and type of meat supplied.
#    4. Previous consumer ratings of vendor and amount of sales.
#    5. Type of meat and average distance traveled to location.
# ---
# b. i. An "end-user" application of this data would be an interface where the consumer could track where the meats been, the shipping prices, and view final prices based on location.
# ---
# b. ii. Attributes would include shop names, shop locations, shipping companies, meat types, vendor names (farms), and transport type.
# ---
# c. We do not have any relevent images to add for this idea.
# ---
# d. The end goal of this database is to help companies make economical, health-conscious decisions when it comes to supplying meat products to their stores.
# ---
#
# ***

# %% [markdown]
# ### Idea 3
#
# a. i. This idea is to see the relationships at restaurants, such as items that customers frequently order, inventory/pricing.
# ---
# a. ii. This idea is unique because we are analyzing unique relationships at restaurants.
# ---
# a. iii. This idea borrows from a typical restaurant setting.
# ---
# a. iv.
# ---
#    1. Menu items and their costs.
#    2. Frequency of menu items ordered.
#    3. Price of ingredients.
#    4. Shipping costs of ingredients.
#    5. Restuarant servers.
# ---
# b. i. The end-user data is idea 2 listed above.
# ---
# b. ii. Attributes would include menu items, ingredients, customers, and servers
# ---
# c. We do not have any relevent images to add for this idea.
# ---
# d. The goal of this idea is to see the relationships at restaurants
# ---
#
# ***
